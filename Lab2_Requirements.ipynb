# %% [markdown]
# #### PRIMEIRA QUESTAO - Você foi contratado para desenvolver o sistema de Ash, um exímio caçador de Pokemons. Crie um menu onde Ash possa 1) Inserir um Pokemon (para cadastrar, solicite nome e idade do pokemon); 2) Procurar o Pokemon pelo nome; 3) Remover o Pokemon pelo nome; 4) imprimir todos os Pokemons cadastrados; 5) Sair do Programa.
#
# ### Implemente uma lista duplamente encadeada como estrutura de dados para armazenar os pokemons.

# %% [markdown]
# #### SEGUNDA QUESTÃO: Implemente a fila de impressão da xérox da área II. Use uma lista encadeada onde o Sr. Armando possa 1) inserir um aluno na fila; 2) Fazer a fila andar; 3) mostrar o status da fila;

# %% [markdown]
# #### TERCEIRA QUESTÃO: Que tal transformar a estrutura de dados da _Questão 2_ em uma pilha? Adapte a questão para um problema onde o uso de uma pilha faz sentido.

# %% [markdown]
# #### QUARTA QUESTAO - Escreva um programa que cadastre escolas (nome, endereço). Para cada escola, você pode adicionar vários alunos (cpf, nome). Crie uma classe para cada uma dessas entidades (escola e aluno).
#
# Crie um menu com as seguintes opções:
#
# 1)adicionar escola;
#
# 2) imprimir todas as escolas cadastradas;
#
# 3)cadastrar aluno em uma determinada escola;
#
# 4) imprimir todos os alunos de uma escola;
#
# 5) imprimir todos os alunos de todas as escolas

# %% [markdown]
# ### QUINTA QUESTAO - Faça a plotagem das funções $f(x) = x^2+3x$ e $g(x)=2^x+6$ em um mesmo gráfico para x>=0 e x<=5

# %% [markdown]
# ### SEXTA QUESTAO - Faça a plotagem das funções $f(x) = x^2+3x$ e $g(x)=2^x+6$ em um mesmo gráfico para x>=10 e x<=20

# %% [markdown]
# ### OITAVA QUESTAO - Adicione contadores de instruções para o seguinte código abaixo. Gere um gráfico de 100 valores para $n$. Encontre também a função de custo teórica da função abaixo.

# %%
def verificaPrimalidade(n):
    cont=2
    ehPrimo = True
    while(cont < n):
        if (n % cont == 0):
            ehPrimo=False
        cont+=1
    return ehPrimo

# %% [markdown]
# ### DÉCIMA QUESTAO -
#
# Crie um código para descobrir os parâmetros $c_1$ e $c_2$, para um $n_0$ fixo, tais que
#
# ---
#
# $c_1 n^4   \leq 2*n^4 - n + 8 \leq c_2 n^4 $, para $n>n_0$.
#
# ---

# %% [markdown]
# ### DÉCIMA PRIMEIRA QUESTAO - Verifique se as sentenças abaixo são verdadeiras ou falsas. Justifique.
#
# $n^2+ 3n + 3 = O(n^2)$
#
# $10n^2= O(n)$
#
# $30n^{30}= \Omega (n)$
#
#
# $99999 n^{10}+ 99n^9 + 999 n^8 = \Omega(n^{11})$
#
# $30n^{30} + 20n= \Theta (n^{30})$
#
# $30n^{3} + 8n= \Theta (n^7)$
#
# $4n^{3} + n= \Theta (n^2)$

# %% [markdown]
# Estudem a relação little o e little w, também!
